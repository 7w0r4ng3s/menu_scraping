# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data.csv').drop('index', 1)

# %%
df
# Out:
#                                          food  pref
# 0                              Armenian Salad     0
# 1                              Armenian Salad     0
# 2                Asian Flank Steak w/Teriyaki     1
# 3                        Asian Pork Spareribs     1
# 4                         Atomic Cheese Sauce     0
# 5                      Authentic Spanish Rice     0
# 6                       BAR Boardwalk Burgers     1
# 7                       BAR Boardwalk Burgers     0
# 8                          BAR Middle Eastern     0
# 9                        BAR Yakisoba Noodles     0
# 10                           BBQ Beef Brisket     1
# 11                          BBQ Shredded Pork     1
# 12                                      Bacon     1
# 13                            Baja Fish Tacos     1
# 14                              Baja Taco Bar     0
# 15               Baked Potatoes with Toppings     1
# 16                Banana and Coconut Pancakes     1
# 17                                 Bar Indian     0
# 18                                  Bar Pasta     1
# 19                                  Bar Pasta     1
# 20                               Bar Taqueria     0
# 21                               Bar Taqueria     0
# 22                         Beef and Lamb Gyro     1
# 23                         Beef and Lamb Gyro     0
# 24                                Bengan Aloo     0
# 25                                Black Beans     0
# 26                         Blueberry Pancakes     1
# 27                         Blueberry Pancakes     1
# 28                                  Bread Bun     0
# 29                   Burger Bar #1 Condiments     0
# ..                                        ...   ...
# 194               Steamed Seasonal Vegetables     0
# 195               Steamed Seasonal Vegetables     0
# 196               Steamed Seasonal Vegetables     0
# 197                               Sticky Rice     1
# 198                       Stir Fry Vegetables     0
# 199  Stuffed Shells in classic Marinara Sauce     0
# 200                Szechuan Sweet Chili Sauce     1
# 201                            Tabouleh Salad     0
# 202                              Tahini Sauce     0
# 203                              Tahini Sauce     0
# 204                          Taqueria Chicken     1
# 205                          Taqueria Chicken     0
# 206                                Tator Tots     1
# 207                    Teriyaki Chicken Shoyu     1
# 208              Teriyaki Sauce (Gluten Free)     1
# 209                        Texas French Toast     1
# 210                        Texas French Toast     1
# 211           Thai Coconut Curry Chicken Soup     0
# 212                        Tomato Bisque Soup     1
# 213                          Turkey Corn Dogs     0
# 214                      Turkey Sausage Patty     1
# 215                     Tuscan Vegetable Soup     0
# 216                            Tzatziki Sauce     0
# 217                            Tzatziki Sauce     0
# 218                   Vegan Macaroni & Cheese     0
# 219                       Vegan Malibu Burger     0
# 220                       Vegan Malibu Burger     0
# 221                         Vegetable Lo Mein     0
# 222                         Veggie Fried Rice     0
# 223                      Veggie Supreme Pizza     0
#
# [224 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 2 columns):
# food    224 non-null object
# pref    224 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 3.6+ KB

# %%
foods = df['food'].unique()
foods
# Out:
# array(['Armenian Salad', 'Asian Flank Steak w/Teriyaki',
#        'Asian Pork Spareribs', 'Atomic Cheese Sauce',
#        'Authentic Spanish Rice', 'BAR Boardwalk Burgers',
#        'BAR Middle Eastern', 'BAR Yakisoba Noodles', 'BBQ Beef Brisket',
#        'BBQ Shredded Pork', 'Bacon', 'Baja Fish Tacos', 'Baja Taco Bar',
#        'Baked Potatoes with Toppings', 'Banana and Coconut Pancakes',
#        'Bar Indian', 'Bar Pasta', 'Bar Taqueria', 'Beef and Lamb Gyro',
#        'Bengan Aloo', 'Black Beans', 'Blueberry Pancakes', 'Bread Bun',
#        'Burger Bar #1 Condiments', 'Burger Bar #2 Condiments',
#        'Burger Beef', 'Buttermilk Pancakes', 'Cage Free Scrambled Eggs',
#        'California Pasta', 'Char Siu Sauce', 'Char Siu Seitan',
#        'Charro Beans', 'Cheese Enchiladas', 'Cheese Pizza',
#        'Cheese Ravioli', 'Cheesy Garlic Bread Sticks', "Chef's Special",
#        'Chicken Apple Sausage', 'Chicken Breast Milanese',
#        'Chicken Mango Sausage', 'Chicken Noodle Soup', 'Chicken Nuggets',
#        'Chicken Tenders', 'Chicken Tortilla Soup', 'Chili con Carne',
#        'Chipotle Gardein Strips', 'Chipotle Seitan Fajitas',
#        'Cilantro Flatbread with Red Onions and Mushrooms',
#        'Coconut Syrup', 'Condiments', 'Corn Tortillas',
#        'Creamy Alfredo Sauce', 'Creamy Broccoli Cheddar Soup',
#        'Creamy Polenta', 'Crispy Bacon', 'Falafels',
#        'Fiesta Taquito Salad', 'French Fries', 'French Waffles',
#        'Fried Chicken', 'Garlic Mashed Yukon Golds',
#        'Grilled Huli Huli Chicken', 'Grilled Pineapple Rings',
#        'Ham Steaks', 'Hard-boiled Cage Free Eggs', 'Hash Brown Patty',
#        'Hawaiian Bar', 'Island BBQ Chicken', 'Lime Cilantro Basmati Rice',
#        'Mac & Cheese', 'Mac and Cheese Bar', 'Madras Chicken',
#        'Marinara Sauce', 'Masala Vegetables', 'Meatball Bar', 'Meatballs',
#        'Memphis Meatloaf', 'Mexican Rice', 'N.E.Clam Chowder',
#        'Natural BridgesTofu Scramble', 'Oatmeal Gluten-Free',
#        'Onion Rings', 'Original Naan',
#        'Oven Roasted Allergen Free Chicken Thigh',
#        'Oven Roasted Herbed Potatoes', 'Peanut Kung Pao Chicken',
#        'Peanut Kung Pao Vegetables', 'Penne', 'Pepperoni Pizza',
#        'Pizza Special', 'Pork Al Pastor', 'Pork Carnitas', 'Pork Pozole',
#        'Portabello Tofu Fried Rice', 'Potato Mac Salad',
#        "Potatoes O'Brien", 'Red Skin Mashed Potatoes', 'Roasted Corn',
#        'Roasted Seasonal Vegetables', 'Roasted Vegetables',
#        'Roasted Yukon Gold Potatoes', 'Roma Pesto Pizza',
#        'Rosemary Roasted Pork Loin', 'Sausage Patties',
#        'Sauteed Mushrooms', 'Sesame Yakisoba Noodles',
#        'Spicy Arrabbiata Sauce',
#        'Spicy Vegan Chicken and Broccoli Stir Fry', 'Steak Cut Fries',
#        'Steamed Rice', 'Steamed Seasonal Vegetables', 'Sticky Rice',
#        'Stir Fry Vegetables', 'Stuffed Shells in classic Marinara Sauce',
#        'Szechuan Sweet Chili Sauce', 'Tabouleh Salad', 'Tahini Sauce',
#        'Taqueria Chicken', 'Tator Tots', 'Teriyaki Chicken Shoyu',
#        'Teriyaki Sauce (Gluten Free)', 'Texas French Toast',
#        'Thai Coconut Curry Chicken Soup', 'Tomato Bisque Soup',
#        'Turkey Corn Dogs', 'Turkey Sausage Patty',
#        'Tuscan Vegetable Soup', 'Tzatziki Sauce',
#        'Vegan Macaroni & Cheese', 'Vegan Malibu Burger',
#        'Vegetable Lo Mein', 'Veggie Fried Rice', 'Veggie Supreme Pizza'],
#       dtype=object)

# %%
len(foods)
# Out:
# 133

# %%
rice = df.loc[df['food'] == 'Steamed Rice']
rice
# Out:
#              food  pref
# 183  Steamed Rice     1
# 184  Steamed Rice     1
# 185  Steamed Rice     1
# 186  Steamed Rice     1
# 187  Steamed Rice     1
# 188  Steamed Rice     1
# 189  Steamed Rice     1

# %%
rice.iloc[:, 1].sum()
# Out:
# 7

# %%
def calc_score(food_name):
    new_df = df.loc[df['food'] == food_name]
    num_like = new_df['food'].count() # total times the food appears
    score = new_df.iloc[:, 1].sum(0) # number of times you like it
    # TODO: add preference evaluation
    print('-' * 50)
    print(f'Out of {num_like} time(s), you clicked "like" {score} time(s)')
    print('-' * 50)

# %%
calc_score(input())
# Out:
# Cheese Pizza
# --------------------------------------------------
# Out of 5 time(s), you clicked "like" 5 time(s)
# --------------------------------------------------
